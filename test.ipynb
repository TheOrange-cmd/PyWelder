# %% [markdown]
# # Imports

# %%
# general imports
import requests
from bs4 import BeautifulSoup 
import re
from html import unescape
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import os
from tabulate import tabulate
import numpy as np

# Imports related to google API
from google.oauth2 import credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.auth.transport.requests import Request


import gspread
import gspread_dataframe as gd
import base64

# Library for fuzzy comparison of strings
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# # Fetch and Parse

# %%
# Fetch the web page
web_page_url = 'https://knkf-sectiepowerliften.nl/kalender/'
response = requests.get(web_page_url)
html = response.text

# %%
# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')

# Find elements based on class name "post"
post_elements = soup.find_all('section', class_='post')

# Function to recursively get the entire HTML structure of an element
def get_full_structure(element):
    return "".join([str(tag) for tag in element.contents])

# Print the entire structure of each post element
for index, post in enumerate(post_elements, start=1):
    print(f"=== Post {index} ===")
    print(get_full_structure(post))
    print("=================")

# %% [markdown]
# # Helper functions and class

# %%
# Define the mapping of abbreviated months to full months
month_mapping = {
    "jan": "January",
    "feb": "February",
    "mar": "March",
    "apr": "April",
    "mei": "May",
    "jun": "June",
    "jul": "July",
    "aug": "August",
    "sep": "September",
    "okt": "October",
    "nov": "November",
    "dec": "December"
}



def ordinal_suffix(day):
    return str(day)+("th" if 4<=day%100<=20 else {1:"st",2:"nd",3:"rd"}.get(day%10, "th"))

def dtStylish(dt, compact=False):

    return dt.strftime(f"%a the {{th}}{' of %B %Y' if not compact else ''} ").replace("{th}", ordinal_suffix(dt.day))


regex_pattern_two_days = r'(\d{1,2})\s*-\s*(\d{1,2})\s*([a-zA-Z]+)'
# This function expects a string of the format "## - ## AAA." where # represents a number from 1-31 and A represents any letter
# I use regex to convert the string to a datetime object
def get_signup_date(date_string):
    try:
        # The regular expression splits the string into the starting date, ending date and abbreviated month
        start_day, end_day, month_abbrev = re.match(regex_pattern_two_days, date_string).groups() 
    except AttributeError:
        # In case the event is only one day, there is only one date given, so we can just split
        #print(f"Found single day: {date_string.split(' ')}")
        start_day, month_abbrev = date_string.split(" ")
        end_day = start_day

    # Get the current year since it's not included in the string
    current_year = datetime.now().year

    # Create datetime objects
    start_date = datetime(current_year, list(month_mapping.keys()).index(month_abbrev) + 1, int(start_day))
    end_date = datetime(current_year, list(month_mapping.keys()).index(month_abbrev) + 1, int(end_day))
    
    # Now if we find that the upcoming event is in the past, that means that the event will actually be next year instead of this year. 
    # So we take the same month and day but just increment the year by 1.
    if datetime.now() > start_date:
        start_date = datetime(current_year+1, list(month_mapping.keys()).index(month_abbrev) + 1, int(start_day))
        end_date = datetime(current_year+1, list(month_mapping.keys()).index(month_abbrev) + 1, int(end_day))
        
    # The KNKF has put on their website that they will open the competition for signup 60 days before the competition. 
    signup_date = start_date-timedelta(days=60)
    return signup_date, start_date, end_date

# Define a class to hold event information
class Event:
    def __init__(self, name, signup_date, start_date, end_date, location, organisation, link, notes=None):
        self.name = name
        self.signup_date = signup_date
        self.start_date = start_date
        self.end_date = end_date
        self.location = location
        self.organisation = organisation
        self.link = link
        self.notes = notes
        
    def __str__(self):
        return (
            f"Event Name: {self.name}\n"
            f"Early Signup Deadline: {dtStylish(self.signup_date)}\n"
            f"Date of Event: {dtStylish(self.start_date, True)}to {dtStylish(self.end_date)}\n"
            f"Location: {self.location}\n"
            f"Organisation: {self.organisation}\n"
            f"Link: {self.link}\n"
            f"Notes: {self.notes}\n"
        )
    
    def __eq__(self, other):
        if isinstance(other, Event):
            return (
                self.name == other.name and
                self.signup_date == other.signup_date and
                self.start_date == other.start_date and
                self.end_date == other.end_date and
                self.location == other.location and
                self.organisation == other.organisation and
                self.link == other.link and
                self.notes == other.notes
            )
        return False
            
    def event_to_dataframe(self):
        data = {
            "Name": [self.name],
            "Signup Date": [self.signup_date],
            "Start Date": [self.start_date],
            "End Date": [self.end_date],
            "Location": [self.location],
            "Organisation": [self.organisation],
            "Link": [self.link],
            "Notes": [self.notes]
        }
        df = pd.DataFrame(data)
        return df
    
    @classmethod
    def from_dataframe(cls, df):
        return cls(
            name=df["Name"].iloc[0],
            signup_date=df["Signup Date"].iloc[0],
            start_date=df["Start Date"].iloc[0],
            end_date=df["End Date"].iloc[0],
            location=df["Location"].iloc[0],
            organisation=df["Organisation"].iloc[0],
            link=df["Link"].iloc[0],
            notes=df["Notes"].iloc[0]
        )
        





def get_credentials(type):
    
    if type.lower() == "drive":
        SCOPES = ["https://www.googleapis.com/auth/drive.file"]  # Use the appropriate scope for the Google Drive API
        TOKEN_FILE = "drive_token.json"
    elif type.lower() == "forms":
        SCOPES = ['https://www.googleapis.com/auth/forms.body', 
                  'https://www.googleapis.com/auth/forms.responses.readonly']
        TOKEN_FILE = "form_token.json"
    elif type.lower() == "scripts":
        SCOPES = ['https://www.googleapis.com/auth/script.projects', 'https://www.googleapis.com/auth/forms']
        TOKEN_FILE = "scripts_token.json"
    elif type.lower() == "read_mail":
        SCOPES = ['https://www.googleapis.com/auth/gmail.readonly', 'https://www.googleapis.com/auth/gmail.modify', 'https://mail.google.com/']
        TOKEN_FILE = "read_mail_token.json"
    else:
        print("Unsupported credential type. Please enter a supported type or implement the missing type.")
        return None
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file("client_secrets.json", SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, "w") as token:
            token.write(creds.to_json())
    return creds



# Function to calculate similarity score using fuzzywuzzy
def calculate_similarity(user_name, name):
    return fuzz.token_sort_ratio(user_name, name)
athlete_status = pd.read_pickle('athlete_status.pkl')
# Set a threshold for acceptance
threshold = 80  # You can adjust this value based on your needs

def find_name(name):
    # Apply the function to the DataFrame and get the best match
    athlete_status["SimilarityScore"] = athlete_status["Name"].apply(calculate_similarity, args = (name,))
    best_match_row = athlete_status[athlete_status["SimilarityScore"] >= threshold].sort_values(by="SimilarityScore", ascending=False).iloc[0]

    # Extract the best match and its similarity score
    best_match = best_match_row["Name"]
    similarity_score = best_match_row["SimilarityScore"]

    # Compare the similarity score with the threshold
    if similarity_score >= threshold:
        print(f"Closest match: {best_match} (Similarity: {similarity_score}%)")
        status = athlete_status.loc[athlete_status["Name"]== best_match]
        return status[["Participate", "Student"]].values.tolist()[0]
    else:
        print("No acceptable match found.")
        return ["ERROR", "Name not found"]

# %% [markdown]
# # Generate tokens

# %%
# Setup authentication and authorization with the drive and forms APIs
drive_creds = get_credentials("drive")
forms_creds = get_credentials("forms")
mail_creds = get_credentials("read_mail")

DRIVE_DISCOVERY_DOC = "https://www.googleapis.com/discovery/v1/apis/drive/v3/rest"
FORMS_DISCOVERY_DOC = "https://forms.googleapis.com/$discovery/rest?version=v1"
MAIL_DISCOVERY_DOC = "https://gmail.googleapis.com/$discovery/rest?version=v1"

drive_service = build("drive", "v3", credentials=drive_creds, discoveryServiceUrl=DRIVE_DISCOVERY_DOC)
forms_service = build('forms', 'v1', credentials=forms_creds, discoveryServiceUrl=FORMS_DISCOVERY_DOC, static_discovery=False)
mail_service = build('gmail', 'v1', credentials=mail_creds, discoveryServiceUrl=MAIL_DISCOVERY_DOC)


# ID of the google drive folder to work in 
folder_id = "12xhQ_a1WQj4sJu7jwHzvdtbrKaPaVDcW"

# %% [markdown]
# # Finding competions

# %%
# List to store event objects
events = []
# We have two kinds of posts on the page. They vary enough that they should be handled separately.
# The first type is for competitions coming soon; they are already open for signup with the KNKF.
for post in post_elements:
    if not "style" in post.attrs:
        continue    # These posts have a style attribute in the html, while the later competitions do not
    
    name_element = post.find('h2').find('a')
    event_name = name_element.text.strip() if name_element else ""
    if "Masters" in event_name:
        continue    # Since we never have Masters athletes, we don't need to announce these competitions
    
    event_link = name_element['href'] if name_element else ""
    
    date_location_element = post.find('p')
    event_date_location = date_location_element.get_text(strip=True) if date_location_element else ""
    event_date, event_location = event_date_location.split("•") if "•" in event_date_location else ("", "")
    signup_date, start_date, end_date = get_signup_date(event_date)
    # event_date = event_date.split(" ")
    # event_date = month_mapping[event_date[3][:-1]] + " " + "".join(event_date[0:3]) + " " + event_date[4] 
    
    organisation_element = post.find('p', class_='intro')
    event_organisation = organisation_element.text.strip() if organisation_element else "No organisation found"
    # Create Event object and add it to the list
    event = Event(event_name.strip(), signup_date, start_date, end_date, event_location.strip(), event_organisation.strip()[13:], event_link.strip(), "Officially open for signup with the KNKF. Don't wait too long!")
    events.append(event)
    
# Extract information from the competitions coming later. These are defined in the last post
post = post_elements[-1]
date_pattern = re.compile(r'\d{1,2}\s+[a-zA-Z&]{2,}')  # Date pattern in Dutch
date_paragraphs = []

for paragraph in post.find_all('p'):
    #print(paragraph)
    paragraph_text = unescape(paragraph.get_text())  # Decode HTML entities
    #print(paragraph_text)
    if "Wedstrijdinschrijvingen openen 60 dagen" in paragraph_text:
        break
    if date_pattern.search(paragraph_text):
        date_paragraphs.append(paragraph_text.split('\n'))

for paragraph in date_paragraphs:
    event_notes = []
    #print(f"par split returns: {paragraph[0].split(':')}")
    event_date, event_name = paragraph[0].split(':')
    if any([word in event_name.lower() for word in ["masters", "vergadering"]]):
        continue
    event_date = event_date.replace("&", "-")
    if "-" in event_date:
        event_date = event_date.split()
        event_date = " ".join(event_date[0:-1]) + " " + event_date[-1][0:3]
    else:
        event_date = event_date.split(" ")
        event_date = event_date[0] + " " + event_date[1][0:3]
    #print(event_date)
    signup_date, start_date, end_date = get_signup_date(event_date)
    if signup_date < events[-1].signup_date:
        signup_date += timedelta(days=365)
        start_date += timedelta(days=365)
        end_date += timedelta(days=365)
    # event_date = event_date + " " + dtStylish(signup_date)[-4:]
    # event_date = event_date.split(" ")
    # event_date = month_mapping[event_date[3]] + " " + "".join(event_date[0:3]) + " " + event_date[4] 
    
    if '&' in event_name:
        event_name = event_name.split('&')[0]
    location_line = paragraph[1].split('-')
    if len(location_line) > 2:
        event_notes.append(location_line[2].strip().capitalize() +".")
    event_location = location_line[0]
    event_organisation = location_line[1]
    if len(paragraph) > 2:
        event_notes.append(paragraph[2].strip().capitalize())
    event_notes = ' '.join(event_notes)
    if event_notes == "":
        event_notes = "None."
    if start_date > datetime.now() + relativedelta(months=6):
        break
    event = Event(event_name.strip(), signup_date, start_date, end_date, event_location.strip(), event_organisation.strip(), "No link available yet", event_notes)
    events.append(event)
    

for event in events:
    print(f"{event}")
# Out:
# Event Name: SBD Cup
# Early Signup Deadline: Tue the 11th of July 2023
# Date of Event: Sat the 9th to Sun the 10th of September 2023
# Location: Nijmegen
# Organisation: NKV Atlas
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/sbd-cup/
# Notes: Officially open for signup with the KNKF. Don't wait too long!
#
# Event Name: Open NK Bankdrukken & Speijers Sports Cup
# Early Signup Deadline: Wed the 2nd of August 2023
# Date of Event: Sun the 1st to Sun the 1st of October 2023
# Location: Beuningen
# Organisation: Speijers Sports
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/open-nk-bankdrukken/
# Notes: Officially open for signup with the KNKF. Don't wait too long!
#
# Event Name: Odin Cup
# Early Signup Deadline: Tue the 8th of August 2023
# Date of Event: Sat the 7th to Sun the 8th of October 2023
# Location: Eindhoven
# Organisation: ESKV Odin
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/odin-cup/
# Notes: Officially open for signup with the KNKF. Don't wait too long!
#
# Event Name: Open Bankdruk Cup Classic
# Early Signup Deadline: Wed the 6th of September 2023
# Date of Event: Sun the 5th to Sun the 5th of November 2023
# Location: Eindhoven
# Organisation: Team Francke powerlifting
# Link: No link available yet
# Notes: None.
#
# Event Name: NSK Powerliften
# Early Signup Deadline: Tue the 19th of September 2023
# Date of Event: Sat the 18th to Sun the 19th of November 2023
# Location: Delft
# Organisation: DSKV IJzersterk
# Link: No link available yet
# Notes: Tot 2 platformen. Studentenstatus + kwalificatietotaal vereist.
#
# Event Name: Benelux Cup
# Early Signup Deadline: Tue the 26th of September 2023
# Date of Event: Sat the 25th to Sun the 26th of November 2023
# Location: Tilburg
# Organisation: TSKV Spartacus
# Link: No link available yet
# Notes: Internationale wedstrijd. deelname op uitnodiging.
#
# Event Name: Lichtstad Cup (Open Powerlifting)
# Early Signup Deadline: Tue the 17th of October 2023
# Date of Event: Sat the 16th to Sun the 17th of December 2023
# Location: Veldhoven
# Organisation: Sportarena
# Link: No link available yet
# Notes: Tot 2 platformen.

# %% [markdown]
# # Manual edit

# %%
events[0].notes = "Full. Signup for waiting list only."
events[2].notes = "Full. Signup for waiting list only."
for event in events:
    print(event)
# Out:
# Event Name: SBD Cup
# Early Signup Deadline: Tue the 11th of July 2023
# Date of Event: Sat the 9th to Sun the 10th of September 2023
# Location: Nijmegen
# Organisation: NKV Atlas
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/sbd-cup/
# Notes: Full. Signup for waiting list only.
#
# Event Name: Open NK Bankdrukken & Speijers Sports Cup
# Early Signup Deadline: Wed the 2nd of August 2023
# Date of Event: Sun the 1st to Sun the 1st of October 2023
# Location: Beuningen
# Organisation: Speijers Sports
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/open-nk-bankdrukken/
# Notes: Officially open for signup with the KNKF. Don't wait too long!
#
# Event Name: Odin Cup
# Early Signup Deadline: Tue the 8th of August 2023
# Date of Event: Sat the 7th to Sun the 8th of October 2023
# Location: Eindhoven
# Organisation: ESKV Odin
# Link: https://knkf-sectiepowerliften.nl/kalender/2023/odin-cup/
# Notes: Full. Signup for waiting list only.
#
# Event Name: Open Bankdruk Cup Classic
# Early Signup Deadline: Wed the 6th of September 2023
# Date of Event: Sun the 5th to Sun the 5th of November 2023
# Location: Eindhoven
# Organisation: Team Francke powerlifting
# Link: No link available yet
# Notes: None.
#
# Event Name: NSK Powerliften
# Early Signup Deadline: Tue the 19th of September 2023
# Date of Event: Sat the 18th to Sun the 19th of November 2023
# Location: Delft
# Organisation: DSKV IJzersterk
# Link: No link available yet
# Notes: Tot 2 platformen. Studentenstatus + kwalificatietotaal vereist.
#
# Event Name: Benelux Cup
# Early Signup Deadline: Tue the 26th of September 2023
# Date of Event: Sat the 25th to Sun the 26th of November 2023
# Location: Tilburg
# Organisation: TSKV Spartacus
# Link: No link available yet
# Notes: Internationale wedstrijd. deelname op uitnodiging.
#
# Event Name: Lichtstad Cup (Open Powerlifting)
# Early Signup Deadline: Tue the 17th of October 2023
# Date of Event: Sat the 16th to Sun the 17th of December 2023
# Location: Veldhoven
# Organisation: Sportarena
# Link: No link available yet
# Notes: Tot 2 platformen.

# %% [markdown]
# # Create new form

# %%
# Form 'updates': all modifications to go from the default form to the required form 

# Request body for creating a Google Form file in the specified folder
NEW_FORM = {
    "name": "Competition Signup Form",
    "parents": [folder_id],
    "mimeType": "application/vnd.google-apps.form"
}

with open("form_description.txt", "r", encoding="utf-8") as file:
    new_description = file.read()

update_description = {
    "requests" : [{
        "updateFormInfo" : {
            "info" : {
                "description": new_description
            },
            "updateMask" : "description"
        }
    }]
}

name_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "What is your name?",
                "questionItem": {
                    "question": {
                        "required": True,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 0
            }
        }
    }]
}

competitions = [
    {
        "value": f"{event.name} on {dtStylish(event.start_date, True)} to {dtStylish(event.end_date)}in {event.location}"
    }
    for event in events
    if "deelname op uitnodiging" not in event.notes.lower()
]

competition_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Select all competitions you want to sign up for:",
                "questionItem": {
                    "question": {
                        "required": True,
                        "choiceQuestion": {
                            "type": "CHECKBOX",
                            "options": competitions,
                            "shuffle": False
                        }
                    }
                },
            },
            "location": {
                "index": 1
            }
        }
    }]
}

weightclass_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "What weightclass do you want to compete in?",
                "questionItem": {
                    "question": {
                        "required": True,
                        "choiceQuestion": {
                            "type": "DROP_DOWN",
                            "options": [
                                {"value": "F47-"},
                                {"value": "F52-"},
                                {"value": "F57-"},
                                {"value": "F63-"},
                                {"value": "F69-"},
                                {"value": "F76-"},
                                {"value": "F84-"},
                                {"value": "F84+"},
                                {"value": "M59-"},
                                {"value": "M66-"},
                                {"value": "M74-"},
                                {"value": "M83-"},
                                {"value": "M93-"},
                                {"value": "M105-"},
                                {"value": "M120-"},
                                {"value": "M120+"},
                            ],
                            "shuffle": False
                        }
                    }
                },
            },
            "location": {
                "index": 2
            }
        }
    }]
}

squat_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter an estimate for your potential squat for this competition. This is used to determine the order of the lifters.",
                "questionItem": {
                    "question": {
                        "required": True,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 3
            }
        }
    }]
}

bench_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter an estimate for your potential bench press for this competition. This is used to determine the order of the lifters.",
                "questionItem": {
                    "question": {
                        "required": True,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 4
            }
        }
    }]
}

deadlift_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter an estimate for your potential deadlift for this competition. This is used to determine the order of the lifters.",
                "questionItem": {
                    "question": {
                        "required": True,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 5
            }
        }
    }]
}

coach_name_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter your coaches name if you have one already.",
                "questionItem": {
                    "question": {
                        "required": False,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 6
            }
        }
    }]
}

coach_knkf_number_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter your coaches KNKF number if you have one already.",
                "questionItem": {
                    "question": {
                        "required": False,
                        "textQuestion": {}
                    }
                },
            },
            "location": {
                "index": 7
            }
        }
    }]
}

coach_dob_question = {
    "requests": [{
        "createItem": {
            "item": {
                "title": "Enter your coaches date of birth if you have one already.",
                "questionItem": {
                    "question": {
                        "required": False,
                        "dateQuestion": {
                            "includeTime": False,
                            "includeYear": True
                        }
                    }
                },
            },
            "location": {
                "index": 8
            }
        }
    }]
}

# Add request to remove the initial question
remove_question = {
    "requests": [{
        "deleteItem": {
            "location": {
                "index": 9
            }
        }
    }]
}

try:
    # Create the Google Form file in the specified folder
    form_file = drive_service.files().create(body=NEW_FORM, media_body=None).execute()
    
    form_id = form_file['id']
    
    new_questions=[update_description, name_question, competition_question, weightclass_question, 
                   squat_question, bench_question, deadlift_question, coach_name_question, coach_knkf_number_question, coach_dob_question, remove_question]
    # Add your code to add questions to the form (similar to your previous code)
    print(f"Form with form ID {form_id} created in folder with ID: {folder_id}")
    
    
    #print(get_result)
    # Adds the question to the form
    for new_question in new_questions:
        question_setting = forms_service.forms().batchUpdate(formId=form_id, body=new_question).execute()

except HttpError as error:
    print(f"An HTTP error occurred: {error}")

# The following request runs a script in google apps scripts API.
# For now, it changes two things: 
# Set RequireLogin to False so that anyone can respond to the form and not just users in the organization.
# Set ShowLinkToRespondAgain to True so that you can easily respond to the form multiple times.

script_id = 'AKfycbwxlIO07heL90qgH-ZIWFRjgFrW1Il_QlvUWPvrp8c7EIwAtREAWdCaTzdr2JaIINNilg'
creds = get_credentials("scripts")

service = build('script', 'v1', credentials=creds)

# Create an execution request object.
request = {
        'function': 'updateFormSettings',
        'parameters': [form_id]
    }

try:
    # Make the API request.
    response = service.scripts().run(scriptId=script_id,
                                        body=request).execute()

except HttpError as error:
    # The API encountered a problem before the script started executing.
    print(f"An error occurred: {error}")
    print(error.content)

with open("last_accessed.txt", 'w') as f:
        f.write(datetime.now().isoformat())
# Out:
# Form with form ID 1rKf2MrwMx4qwq1oL0y7AWhW7stT7bYejhW7NxcPUWdw created in folder with ID: 12xhQ_a1WQj4sJu7jwHzvdtbrKaPaVDcW

# %%
# Store the new form id into a txt file so we can easily access it later. 
with open("current_form_id.txt", "w") as file:
    file.write(form_id)

# %%
# Store the order of the questions by id, as apparently the responses are not stored in the same order as the questions, but do contain the questionid. 
# After retrieving the responses, the answers can be organized by this id order. 
with open("question_order.txt", "w") as file:
    form = forms_service.forms().get(formId=form_id).execute()
    file.write(' '.join([subsubitem["questionId"] for subsubitem in [subitem["question"] for subitem in [item["questionItem"] for item in form["items"]]]]))

# %% [markdown]
# # Write whatsapp message draft

# %%
# Define input and output file paths
input_file_path = 'whatsapp_msg_def.txt'
output_file_path = 'whatsapp_msg.txt'

# Concatenate string representations of objects
events_string = '\n'.join(str(event) for event in events)
form_id_string = f"https://docs.google.com/forms/d/{form_id}/viewform"

# Read the default content
with open(input_file_path, 'r') as input_file:
    default_content = input_file.read()

# Replace the first occurrence of {} with replacement_string1
modified_content1 = input_content.replace('{}', events_string, 1)

# Replace the second occurrence of {} with replacement_string2
modified_content2 = modified_content1.replace('{}', form_id_string, 1)

# Write the modified content to the output file
with open(output_file_path, 'w') as output_file:
    output_file.write(modified_content2)

# %% [markdown]
# # Load and compare events

# %%
import pickle
import glob

def save_events_to_file(events_list):
    with open(f"events_{datetime.today().strftime('%Y_%m_%d')}.pkl", "wb") as file:
        pickle.dump(events_list, file)

def load_previous_events_from_file():
    with open(f"{glob.glob('*.pkl')[0]}", "rb") as file:
        events_list = pickle.load(file)
    return events_list

def find_new_events(events):
    loaded_events = load_previous_events_from_file()
    return [event for event in events if event not in loaded_events]

# # Save the list to a file
# save_events_to_file(events)

# # Compare the events in the file to the events pulled from the site
# new_events = find_new_events(events)

# %%
with open("last_accessed.txt", 'w') as f:
    f.write(datetime.min.isoformat())

# %% [markdown]
# # Access responses and store into sheet

# %%
SKIP_OLD_DATA = False


with open("current_form_id.txt", 'r') as form_id_file:
    try:
        form_responses = forms_service.forms().responses().list(formId=form_id_file.read()).execute()
    except Exception as e:
        print(e)
        

        
try:
    # Initialize lists to store data
    try:
        # Read the most recent access time
        with open("last_accessed.txt") as f:
            print(f.read)
            last_access = datetime.fromisoformat(f.read())
            print(f"Responses last accessed on {last_access}")
    except FileNotFoundError:
        with open("last_accessed.txt", 'w') as f:
            f.write(datetime.min.isoformat())
    if SKIP_OLD_DATA:
        # Write the current time back
        with open("last_accessed.txt", 'w') as f:
            f.write(datetime.now().isoformat())
    rows = []
    for form_response in form_responses['responses']:
        # createTime is when the form response was submitted. 
        createTime = form_response['createTime']
        createTime_dt = datetime.strptime(createTime, '%Y-%m-%dT%H:%M:%S.%fZ')
        # Skip responses that have already been stored in the database. Adding 2 hrs because google is 2 hrs in the past.
        if createTime_dt + timedelta(hours=2) < last_access:
            print("Response already seen.")
            if SKIP_OLD_DATA:
                continue 
        # Now the answers are extracted
        __, answer_data = zip(*form_response['answers'].items())
        answers = [(answer['questionId'], answer['textAnswers']['answers']) for answer in answer_data]
        # The answers are sorted by their question ids. For some reason, the google API shuffles the answers. 
        # The answers are 'unshuffled' here, pairing question ids with the order of those ids stored earlier.
        with open("question_order.txt", 'r') as question_order_file:
            question_order = question_order_file.read()
        question_order = [str(item) for item in question_order.split(" ")]

        answers_dict = {key: value for key, value in answers}
        answers = [answers_dict.get(key, [{'value': 'None'}]) for key in question_order]
        # Now when someone has signed up for more than one competition, that field 
        # contains multiple values, while all other fields only contain one value.
        # The other values are duplicated so the list-with-a-bump becomes a rectangle. 
        for i in range(len(answers[1])-1):
            answers[0].append(answers[0][0])
            answers[2].append(answers[2][0])
            answers[3].append(answers[3][0])
            answers[4].append(answers[4][0])
            answers[5].append(answers[5][0])
            answers[6].append(answers[6][0])
            answers[7].append(answers[7][0])
            answers[8].append(answers[8][0])
            
         # The answers are still hidden in a few layers. They are unpacked here. 
        answers = np.asarray(answers)
        
            
        for i in range(np.shape(answers)[1]):
            name = answers[0][i].get('value', None)
            competition = answers[1][i].get('value', None)
            weightclass = answers[2][i].get('value', None)
            squat = answers[3][i].get('value', None)
            bench = answers[4][i].get('value', None)
            deadlift = answers[5][i].get('value', None)
            coach_name = answers[6][i].get('value', None)
            coach_number = answers[7][i].get('value', None)
            coach_dob = answers[8][i].get('value', None)
            status = find_name(name)
            print(f"status: {status}")
            row = {
                'Time of Response': createTime,
                'Name': name,
                'Competition': competition,
                'Weightclass': weightclass,
                'Squat': squat,
                'Bench': bench,
                'Deadlift': deadlift,
                'Coach Name': coach_name, 
                'Coach Number' : coach_number,
                'Coach DOB': coach_dob,
                'Doping check': status[0],
                'Student Status': status[1]
            }
            rows.append(row)
        
except KeyError as e:
    print(e)
    print("No responses yet.")

# Create a DataFrame
df = pd.DataFrame(rows)

print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x0000025561D66810>
# Responses last accessed on 2023-08-22 20:13:19.489565
# Response already seen.
# Closest match: Nasreddine Ouchene (Similarity: 100%)
# status: [True, True]
# Response already seen.
# Closest match: Yingkai Song (Similarity: 100%)
# status: [True, True]
# +----+--------------------------+--------------------+-----------------------------------------------------------------------------+---------------+---------+---------+------------+--------------+----------------+-------------+----------------+------------------+
# |    | Time of Response         | Name               | Competition                                                                 | Weightclass   |   Squat |   Bench |   Deadlift | Coach Name   | Coach Number   | Coach DOB   | Doping check   | Student Status   |
# |----+--------------------------+--------------------+-----------------------------------------------------------------------------+---------------+---------+---------+------------+--------------+----------------+-------------+----------------+------------------|
# |  0 | 2023-08-22T11:57:30.266Z | Nasreddine Ouchene | NSK Powerliften on Sat the 18th  to Sun the 19th of November 2023  in Delft | M93-          |     205 |     145 |        250 | None         | None           | None        | True           | True             |
# |  1 | 2023-08-22T16:49:59.182Z | Yingkai Song       | NSK Powerliften on Sat the 18th  to Sun the 19th of November 2023  in Delft | M93-          |     200 |     100 |        245 | Coen de Heer | 547958         | 1996-09-13  | True           | True             |
# +----+--------------------------+--------------------+-----------------------------------------------------------------------------+---------------+---------+---------+------------+--------------+----------------+-------------+----------------+------------------+

# %%
sheet_id = "1WXn5hOe_UzKoiXAQrdaZ6xm6WVCR0tKImuYYkTsI0wo"

gc = gspread.oauth(
    credentials_filename="client_secrets.json",
    authorized_user_filename='gspread_token.json'
)

def next_available_row(worksheet):
    return len(worksheet.col_values(1))+1

# %%
sh = gc.open_by_key(sheet_id)
print(sh.worksheets())
worksheet = sh.worksheets()[0]
print(next_available_row(worksheet))
gd.set_with_dataframe(worksheet=worksheet,dataframe=df,include_index=False,include_column_header=False,row=next_available_row(worksheet),resize=False)
# Out:
# [<Worksheet 'Signups' id:0>, <Worksheet 'Athletes' id:928874941>, <Worksheet 'Color Coding' id:1992401991>]
# 2

# %% [markdown]
# # Reading mail

# %%
try:
    results = mail_service.users().messages().list(maxResults= 1, q="[info] Uitnodiging", userId='me').execute()
    #print((results['messages']))
    print(results)
    messages = results.get('messages',[])
    message_count = 0
    for message in messages:
        message = mail_service.users().messages().get(userId='me', id=message['id']).execute()
        print(message)         
        email_data = message['payload']['headers']
        for values in email_data:
            name = values['name']
            if name == 'From':
                from_name= values['value']                
                for part in message['payload']['parts']:
                    try:
                        data = part['body']["data"]
                        byte_code = base64.urlsafe_b64decode(data)

                        text = byte_code.decode("utf-8")
                        #print ("This is the message: "+ str(text))                                              
                    except BaseException as error:
                        print(error)
                        pass                      
except HttpError as error:
    # TODO(developer) - Handle errors from gmail API.
    print(f'An error occurred: {error}')

main_string = str(text)
keyword = "https://knkf-sectiepowerliften.nl"
ending_symbol = '"'

pattern = re.escape(keyword) + r"(.*?)" + re.escape(ending_symbol)
matches = re.findall(pattern, main_string)

longest_length = 0
longest_match = ""

for match in matches:
    extracted_text = match.strip()
    match_length = len(extracted_text)
    
    if match_length > longest_length:
        longest_length = match_length
        longest_match = extracted_text

print("Longest match:", keyword+longest_match)
# Out:
# {'messages': [{'id': '189f033297d759b5', 'threadId': '189ee389b7314d3e'}], 'nextPageToken': '02376736811317794441', 'resultSizeEstimate': 201}
# {'id': '189f033297d759b5', 'threadId': '189ee389b7314d3e', 'labelIds': ['IMPORTANT', 'CATEGORY_FORUMS', 'INBOX'], 'snippet': 'Uitnodiging Odin Cup 2023 Beste wedstrijdsecretaris van DSKV IJzersterk, Graag nodigen we jullie uit om deel te nemen aan de Odin Cup 2023 op 7 &amp; 8 oktober te Eindhoven. Bekijk alle', 'payload': {'partId': '', 'mimeType': 'multipart/alternative', 'filename': '', 'headers': [{'name': 'Delivered-To', 'value': 'secretaris@ijzersterkdelft.nl'}, {'name': 'Received', 'value': 'by 2002:a05:6a06:1249:b0:634:bed8:d7d7 with SMTP id l9csp2422096piq;        Sun, 13 Aug 2023 11:40:32 -0700 (PDT)'}, {'name': 'X-Received', 'value': 'by 2002:a05:6512:1284:b0:4fe:676:8bf2 with SMTP id u4-20020a056512128400b004fe06768bf2mr5735011lfs.10.1691952032149;        Sun, 13 Aug 2023 11:40:32 -0700 (PDT)'}, {'name': 'ARC-Seal', 'value': 'i=5; a=rsa-sha256; t=1691952032; cv=pass;        d=google.com; s=arc-20160816;        b=iOwkj1yh/d+1PYdtSE4e4hqt3gi1uwEXCP6YpE1qmy+T5NJBoskGf26Grg4boXIBQx         Ov0t9MWa1XL25umfsHnHTrRyG7xd3F8iBdTspFjDPkCw8euxQBncT72UAyLZhGXi4cqe         c9fj8TVDU2lruoOEppYGDNOvaTnXdqWAupn8/2xLzOp1fk28HCZ3JWwyKqA8xMa5X+U3         cnmWaWKX6ROgvNQ1Kr9mDRxP6EuaeH38rWASvCRY8b0gHEj7NTd2j8TA5eOLvLwXSmCG         jXlv+j+NaIKzSZEGByZ35UwrH+BZ1WN7KQvV+uuhTveSGrZ4/dPFSgcV66lDm3lmhqwH         eTyg=='}, {'name': 'ARC-Message-Signature', 'value': 'i=5; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;        h=list-unsubscribe:list-archive:list-help:list-post:list-id         :mailing-list:precedence:content-transfer-encoding:mime-version         :message-id:subject:reply-to:from:to:date:dkim-signature;        bh=9u+yyT4kdHSmVv9+Vj5ZPUc6B9QUEO+wn4TKARhS8Vw=;        fh=6oyMusEzEtsI8MXnoQTCBtqY+JTagP50Zg+EoUFi6Cs=;        b=082qfBMgFNS4dwILhbynO8hYdXzVW2HHu7QrYrUP9BodfHTJFkjkfTGjXTBpOuHpbr         KDdOFHiBYGKIVv7Uv3tSAE9OSbYj5iZBom5md/jDHb47MG8xu0eOu7x0zESYW1Ua7eCp         mLv5ICJ279YF6/+dL7rq4SKgffGtSQjs+3k+7EaJvBNLz+mEjIQoOcRfbfxizJxRAii3         ZmyYkGLn8Qs74M7R6kMrlf3fICvVutfZ4MeBVi3szhtExsUPhZAc+rtitLWbOb6vBEXl         Tm+BEH60T6BCkTlAQS2P5IWzOL46+OxAO0fS7sbJtfFmMvErCXH6dUFskwxfg8C8L0+s         gxYw=='}, {'name': 'ARC-Authentication-Results', 'value': 'i=5; mx.google.com;       dkim=pass header.i=@ijzersterkdelft-nl.20221208.gappssmtp.com header.s=20221208 header.b="0qPpnMl/";       arc=pass (i=4 spf=pass spfdomain=knkf-sectiepowerliften.nl dmarc=pass fromdomain=knkf-sectiepowerliften.nl);       spf=pass (google.com: domain of info+bncbaabbhwh4stamgqeor3oozy@ijzersterkdelft.nl designates 209.85.220.69 as permitted sender) smtp.mailfrom=info+bncBAABBHWH4STAMGQEOR3OOZY@ijzersterkdelft.nl'}, {'name': 'Return-Path', 'value': '<info+bncBAABBHWH4STAMGQEOR3OOZY@ijzersterkdelft.nl>'}, {'name': 'Received', 'value': 'from mail-sor-f69.google.com (mail-sor-f69.google.com. [209.85.220.69])        by mx.google.com with SMTPS id k20-20020a192d14000000b004fddc68513fsor2942483lfj.14.2023.08.13.11.40.31        for <secretaris@ijzersterkdelft.nl>        (Google Transport Security);        Sun, 13 Aug 2023 11:40:32 -0700 (PDT)'}, {'name': 'Received-SPF', 'value': 'pass (google.com: domain of info+bncbaabbhwh4stamgqeor3oozy@ijzersterkdelft.nl designates 209.85.220.69 as permitted sender) client-ip=209.85.220.69;'}, {'name': 'Authentication-Results', 'value': 'mx.google.com;       dkim=pass header.i=@ijzersterkdelft-nl.20221208.gappssmtp.com header.s=20221208 header.b="0qPpnMl/";       arc=pass (i=4 spf=pass spfdomain=knkf-sectiepowerliften.nl dmarc=pass fromdomain=knkf-sectiepowerliften.nl);       spf=pass (google.com: domain of info+bncbaabbhwh4stamgqeor3oozy@ijzersterkdelft.nl designates 209.85.220.69 as permitted sender) smtp.mailfrom=info+bncBAABBHWH4STAMGQEOR3OOZY@ijzersterkdelft.nl'}, {'name': 'ARC-Seal', 'value': 'i=4; a=rsa-sha256; t=1691952031; cv=pass;        d=google.com; s=arc-20160816;        b=ENs+SMV2CuaXY47TfEMgTVBdUcPKCJGevj7sYNUaboULoUmwgcDSzTMKT9DbyG1pFD         7JCMKUK9SUdMqQyf9uyxOIPb1rImGdEbAyPPUMfd72RG5E ...
# Longest match: https://knkf-sectiepowerliften.nl/t/2023-odin-cup/club.php?a=545196&code=bf8b021bcb04fca701d348e2e5f16b96350d3fde9aabf9b5c409f932ac23402a

# %%
web_page_url = keyword+longest_match
web_page_url = web_page_url.replace("club.php", "club-members.php")
response = requests.get(web_page_url)
html = response.text

# %%
class Athlete():
    def __init__(self, name, doping_status, student_status):
            self.name = name
            self.doping_status = doping_status
            self.student_status = student_status
        
    def __str__(self):
        return (
            f"Athlete Name: {self.name}\n"
            f"Doping Status: {self.doping_status}\n"
            f"Student Status: {self.student_status}\n"
        )
    
    def __eq__(self, other):
        if isinstance(other, Event):
            return (
                self.name == other.name and
                self.doping_status == other.doping_status and
                self.student_status == other.student_status   
            )
        return False
    
# Parse the HTML
soup = BeautifulSoup(html, 'html.parser')
#print(soup)
# Find elements based on class name "post"
post_elements = soup.find_all('div', class_='panel-body')
# Function to recursively get the entire HTML structure of an element
def get_full_structure(element):
    return "".join([str(tag) for tag in element.contents])

keyword = "<li>"
ending_symbol = "</li>"
pattern = re.escape(keyword) + r"(.*?)" + re.escape(ending_symbol)

extracted_list = []

# Print the entire structure of each post element
for index, post in enumerate(post_elements, start=1):
    print(f"=== Post {index} ===")
    print(get_full_structure(post))
    print("=================")

    matches = re.findall(pattern, get_full_structure(post))

    for match in matches:
        extracted_text = match.strip()
        extracted_list.append(extracted_text)
        
athletes = []
rows = []

for text in extracted_list:
    sub_soup = BeautifulSoup(text, "html.parser")
    #print(sub_soup)
    name = sub_soup.find(string=True, recursive=False).strip()
    print(f'Name = {name}')
    try:
        deelnemen_coachen = sub_soup.select('a[href*="/anti-doping/"]')[0].next_sibling.strip()
        deelnemen_coachen = ["deelnemen" in deelnemen_coachen, "coachen" in deelnemen_coachen]
    except IndexError:
        deelnemen_coachen = [False, False]
    try: 
        studentenstatus = sub_soup.select('a[href*="/studentenstatus/"]')
        studentenstatus = len(studentenstatus) > 0 
    except IndexError:
        studentenstatus = [False]

    #print(name.strip(" (Wedstrijdlid)"), "#", deelnemen_coachen[0], "#", deelnemen_coachen[1],"#", studentenstatus)
    rows.append({'Name':name.replace(" (Wedstrijdlid)", "").strip(), 'Participate': deelnemen_coachen[0], 'Coaching': deelnemen_coachen[1], 'Student': studentenstatus})
for row in rows:
    print(row)
# Out:
# === Post 1 ===
# <div class="alert alert-info" role="alert">Zorg dat u tijdig wijzigingen aanvraagd en dat uw leden tijdig <a href="https://knkf-sectiepowerliften.nl/kalender/2023/odin-cup/" target="_blank">aan de eisen voldoen</a>. Het kan tot 24 uur duren voordat wijzigingen gesynchroniseerd zijn met ons nominatiesysteem.</div><ol><li>Adriaan Dirkzwager (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen &amp; coachen</small></li><li>Alec Nonnemaker (Wedstrijdlid)<small><br/>Junior<br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen<br/><a href="/leden/studentenstatus/">Studentenstatus</a> (ten tijde van wedstrijd): 1e jaars alumnus</small><br/><a href="https://instagram.com/a1ecm" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Amy Driesse (Wedstrijdlid)<small><br/>Junior<br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen<br/><a href="/leden/studentenstatus/">Studentenstatus</a> (ten tijde van wedstrijd): 1e jaars alumnus</small><br/><a href="https://instagram.com/amy3sse" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Andre Makkinje (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen &amp; coachen</small></li><li>Arvid Maarleveld (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen &amp; coachen</small></li><li>Auke-Jan Jacob Piers (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: -</small><br/>LET OP: IBAN ontbreekt in ledenadministratie! Dit is vereist om in te kunnen schrijven.</li><li>Bram Nijhoff (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen</small><br/><a href="https://instagram.com/bramnij" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Buu van Nguyen (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen</small></li><li>Collin Bakker (Wedstrijdlid)<small><br/>Junior<br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen &amp; coachen</small><br/><a href="https://instagram.com/collinbakker_" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Djordi Kruyt (Wedstrijdlid)<small><br/>Junior<br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen</small></li><li>Eloena Heijerman (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen &amp; coachen<br/><a href="/leden/studentenstatus/">Studentenstatus</a> (ten tijde van wedstrijd): 1e jaars alumnus</small><br/><a href="https://instagram.com/eloena_ch" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Emma Rots (Wedstrijdlid)<small><br/>Junior<br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen<br/><a href="/leden/studentenstatus/">Studentenstatus</a> (ten tijde van wedstrijd): 1e jaars alumnus</small><br/><a href="https://instagram.com/emmasophiacarolina" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Fabbio Hu (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen</small><br/><a href="https://instagram.com/faabbiohu" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Felix Francken (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen<br/><a href="/leden/studentenstatus/">Studentenstatus</a> (ten tijde van wedstrijd): 1e jaars alumnus</small><br/><a href="https://instagram.com/felix.francken" target="_blank"><img src="../plreg-common/resources/ig.png" width="22px"/></a></li><li>Gerben Timmer (Wedstrijdlid)<small><br/><a href="/leden/anti-doping/">Dopingautoriteit E-learing</a>: deelnemen</small></li><li>Grigory Prikazchik ...
# =================
# Name = Adriaan Dirkzwager (Wedstrijdlid)
# Name = Alec Nonnemaker (Wedstrijdlid)
# Name = Amy Driesse (Wedstrijdlid)
# Name = Andre Makkinje (Wedstrijdlid)
# Name = Arvid Maarleveld (Wedstrijdlid)
# Name = Auke-Jan Jacob Piers (Wedstrijdlid)
# Name = Bram Nijhoff (Wedstrijdlid)
# Name = Buu van Nguyen (Wedstrijdlid)
# Name = Collin Bakker (Wedstrijdlid)
# Name = Djordi Kruyt (Wedstrijdlid)
# Name = Eloena Heijerman (Wedstrijdlid)
# Name = Emma Rots (Wedstrijdlid)
# Name = Fabbio Hu (Wedstrijdlid)
# Name = Felix Francken (Wedstrijdlid)
# Name = Gerben Timmer (Wedstrijdlid)
# Name = Grigory Prikazchikov (Wedstrijdlid)
# Name = Hiresh Jadoenathmissier (Wedstrijdlid)
# Name = Hong Jie Zheng (Wedstrijdlid)
# Name = Iris de Lange (Wedstrijdlid)
# Name = Jeroen Koster (Wedstrijdlid)
# Name = Jesse Harte (Wedstrijdlid)
# Name = Joey Ma (Wedstrijdlid)
# Name = Kabir Razack (Wedstrijdlid)
# Name = Kimberley Teeuwissen (Wedstrijdlid)
# Name = Kristof van Kamperdijk (Wedstrijdlid)
# Name = Lucas Lemsom (Wedstrijdlid)
# Name = Luuk Tiel (Wedstrijdlid)
# Name = Luuk Unger (Wedstrijdlid)
# Name = Marijn Craenen (Wedstrijdlid)
# Name = Martin Tan (Wedstrijdlid)
# Name = Max van Stuijvenberg (Wedstrijdlid)
# Name = Mito Apfelstedt (Wedstrijdlid)
# Name = Nasreddine Ouchene (Wedstrijdlid)
# Name = Nathan Smithers (Wedstrijdlid)
# Name = Olivia Meng (Wedstrijdlid)
# Name = Peter Herman Evers (Wedstrijdlid)
# Name = Quinten Doornbos (Wedstrijdlid)
# Name = Ragnhild Maarleveld (Wedstrijdlid)
# Name = Remco van Woerkom (Wedstrijdlid)
# Name = Remi Smith (Wedstrijdlid)
# Name = Rishi Nair (Wedstrijdlid)
# Name = Roy van de Graaf (Wedstrijdlid)
# Name = Ruben Zuidgeest (Wedstrijdlid)
# Name = Ruud Kassing (Wedstrijdlid)
# Name = Stan Bergkamp (Wedstrijdlid)
# Name = Ted de Vries Lentsch (Wedstrijdlid)
# Name = Wessel de Jonge (Wedstrijdlid)
# Name = Wolfgang Bubberman (Wedstrijdlid)
# Name = Yingkai Song (Wedstrijdlid)
# {'Name': 'Adriaan Dirkzwager', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Alec Nonnemaker', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Amy Driesse', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Andre Makkinje', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Arvid Maarleveld', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Auke-Jan Jacob Piers', 'Participate': False, 'Coaching': False, 'Student': False}
# {'Name': 'Bram Nijhoff', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Buu van Nguyen', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Collin Bakker', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Djordi Kruyt', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Eloena Heijerman', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Emma Rots', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Fabbio Hu', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Felix Francken', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Gerben Timmer', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Grigory Prikazchikov', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Hiresh Jadoenathmissier', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Hong Jie Zheng', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Iris de Lange', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Jeroen Koster', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Jesse Harte', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Joey Ma', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Kabir Razack', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Kimberley Teeuwissen', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Kristof van Kamperdijk', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Lucas Lemsom', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Luuk Tiel', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Luuk Unger', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Marijn Craenen', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Martin Tan', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Max van Stuijvenberg', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Mito Apfelstedt', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Nasreddine Ouchene', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Nathan Smithers', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Olivia Meng', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Peter Herman Evers', 'Participate': False, 'Coaching': False, 'Student': False}
# {'Name': 'Quinten Doornbos', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Ragnhild Maarleveld', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Remco van Woerkom', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Remi Smith', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Rishi Nair', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Roy van de Graaf', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Ruben Zuidgeest', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Ruud Kassing', 'Participate': True, 'Coaching': False, 'Student': False}
# {'Name': 'Stan Bergkamp', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Ted de Vries Lentsch', 'Participate': True, 'Coaching': True, 'Student': True}
# {'Name': 'Wessel de Jonge', 'Participate': True, 'Coaching': False, 'Student': True}
# {'Name': 'Wolfgang Bubberman', 'Participate': True, 'Coaching': True, 'Student': False}
# {'Name': 'Yingkai Song', 'Participate': True, 'Coaching': False, 'Student': True}

# %%
df = pd.DataFrame(rows)
df.to_pickle('athlete_status.pkl') 
df1 = pd.read_pickle('athlete_status.pkl')
print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------------------+---------------+------------+-----------+
# |    | Name                    | Participate   | Coaching   | Student   |
# |----+-------------------------+---------------+------------+-----------|
# |  0 | Adriaan Dirkzwager      | True          | True       | False     |
# |  1 | Alec Nonnemaker         | True          | False      | True      |
# |  2 | Amy Driesse             | True          | False      | True      |
# |  3 | Andre Makkinje          | True          | True       | False     |
# |  4 | Arvid Maarleveld        | True          | True       | False     |
# |  5 | Auke-Jan Jacob Piers    | False         | False      | False     |
# |  6 | Bram Nijhoff            | True          | False      | False     |
# |  7 | Buu van Nguyen          | True          | False      | False     |
# |  8 | Collin Bakker           | True          | True       | False     |
# |  9 | Djordi Kruyt            | True          | False      | False     |
# | 10 | Eloena Heijerman        | True          | True       | True      |
# | 11 | Emma Rots               | True          | False      | True      |
# | 12 | Fabbio Hu               | True          | False      | False     |
# | 13 | Felix Francken          | True          | False      | True      |
# | 14 | Gerben Timmer           | True          | False      | False     |
# | 15 | Grigory Prikazchikov    | True          | True       | True      |
# | 16 | Hiresh Jadoenathmissier | True          | True       | False     |
# | 17 | Hong Jie Zheng          | True          | True       | True      |
# | 18 | Iris de Lange           | True          | True       | False     |
# | 19 | Jeroen Koster           | True          | True       | False     |
# | 20 | Jesse Harte             | True          | False      | True      |
# | 21 | Joey Ma                 | True          | True       | False     |
# | 22 | Kabir Razack            | True          | False      | False     |
# | 23 | Kimberley Teeuwissen    | True          | False      | False     |
# | 24 | Kristof van Kamperdijk  | True          | False      | False     |
# | 25 | Lucas Lemsom            | True          | False      | False     |
# | 26 | Luuk Tiel               | True          | True       | False     |
# | 27 | Luuk Unger              | True          | False      | True      |
# | 28 | Marijn Craenen          | True          | False      | True      |
# | 29 | Martin Tan              | True          | True       | False     |
# | 30 | Max van Stuijvenberg    | True          | True       | True      |
# | 31 | Mito Apfelstedt         | True          | False      | True      |
# | 32 | Nasreddine Ouchene      | True          | True       | True      |
# | 33 | Nathan Smithers         | True          | False      | True      |
# | 34 | Olivia Meng             | True          | False      | True      |
# | 35 | Peter Herman Evers      | False         | False      | False     |
# | 36 | Quinten Doornbos        | True          | True       | False     |
# | 37 | Ragnhild Maarleveld     | True          | True       | False     |
# | 38 | Remco van Woerkom       | True          | True       | False     |
# | 39 | Remi Smith              | True          | False      | False     |
# | 40 | Rishi Nair              | True          | True       | True      |
# | 41 | Roy van de Graaf        | True          | False      | True      |
# | 42 | Ruben Zuidgeest         | True          | True       | False     |
# | 43 | Ruud Kassing            | True          | False      | False     |
# | 44 | Stan Bergkamp           | True          | True       | True      |
# | 45 | Ted de Vries Lentsch    | True          | True       | True      |
# | 46 | Wessel de Jonge         | True          | False      | True      |
# | 47 | Wolfgang Bubberman      | True          | True       | False     |
# | 48 | Yingkai Song            | True          | False      | True      |
# +----+-------------------------+---------------+------------+-----------+

# %%
sh = gc.open_by_key(sheet_id)
print(sh.worksheets())
worksheet = sh.worksheets()[1]
gd.set_with_dataframe(worksheet=worksheet,dataframe=df,include_index=False,include_column_header=False,row=2,resize=False)
